# %%
#bibliotecas
import pandas as pd

# %%
#carregar dataset
data = pd.read_csv('probability-of-mismanaged-plastic-waste-being-emitted-to-ocean.csv')

# %%
#Infos do dataset
print(data.head())
print(data.info())
print(data.describe())
print(data.columns)
# Out:
#                Country  Year  ProbabilityEnterOcean
# 0              Albania  2019                   1.56
# 1              Algeria  2019                   0.09
# 2               Angola  2019                   0.09
# 3  Antigua and Barbuda  2019                   3.08
# 4            Argentina  2019                   0.26
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                163 non-null    object
#  1   Year                   163 non-null    int64
#  2   ProbabilityEnterOcean  163 non-null    float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 3.9+ KB
# None
#          Year  ProbabilityEnterOcean
# count   163.0             163.000000
# mean   2019.0               1.749141
# std       0.0               2.621274
# min    2019.0               0.000000
# ...

# %%
#alterações no dataset
data.rename(columns={'Entity': 'Country'}, inplace=True)
data.rename(columns={'Probability of plastic being emitted to ocean': 'ProbabilityEnterOcean'}, inplace=True)

# %%
#visualizações dos dados
data['Country'].unique()
# Out:
# array(['Albania', 'Algeria', 'Angola', 'Antigua and Barbuda', 'Argentina',
#        'Australia', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belgium', 'Belize', 'Benin', 'Bosnia and Herzegovina', 'Brazil',
#        'Brunei', 'Bulgaria', 'Burkina Faso', 'Cambodia', 'Cameroon',
#        'Canada', 'Cape Verde', 'Chile', 'China', 'Colombia', 'Comoros',
#        'Congo', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cyprus',
#        'Democratic Republic of Congo', 'Denmark', 'Djibouti', 'Dominica',
#        'Dominican Republic', 'East Timor', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia', 'Fiji',
#        'Finland', 'France', 'French Guiana', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Greece', 'Grenada', 'Guadeloupe', 'Guatemala',
#        'Guinea', 'Guinea-Bissau', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong', 'Iceland', 'India', 'Indonesia', 'Iran', 'Iraq',
# ...

# %%
data.to_csv('C:\\uni\\ano2\\sem1\\vis_info\\projeto_PLE\\datasets\\probability_countries.csv', index=False)
